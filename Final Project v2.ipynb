# %%
import pandas as pd
import numpy as np
import os
import shutil

# %%
class AlzDiagnosisAlg():
    
    def open_dataframe(file_path):
        #Opens .csv file
        if file_path.endswith('csv'):
            df = pd.read_csv(file_path)
            df = df.drop(columns = 'Unnamed: 0')
        else:
            raise ValueError('File is not in proper .csv format')
        return df
    
    def z_calc(data):
        # calculates z scores for each neuropsych test based on norms derived from this paper: https://files.alz.washington.edu/documentation/weintraub-2018-v3.pdf
        zs = data
        for row in range(zs.shape[0]):
            if zs.iloc[row, 1] < 60:
                zs = zs.assign(Delayed_Recall_Z = lambda x: ((x['Delayed Recall']-20.9)/7.0))
                zs = zs.assign(Number_Span_Test_Forward_Z = lambda x: ((x['Number Span Test Forward']-8.7)/2.4))
                zs = zs.assign(Part_A_Trail_Making_Z = lambda x: ((-x['Part A Trail Making']+22.3)/8.4))
                zs = zs.assign(Part_B_Trail_Making_Z = lambda x: ((-x['Part B Trail Making']+55.4)/27.2))
                zs = zs.assign(MoCA_Z = lambda x: ((x['moca']-27.5)/2.1))
                zs = zs.assign(Categories_Animal_Z = lambda x: ((x['Categories Animal']-23.6)/5.3))
            if 60 <= zs.iloc[row, 1] <= 69:
                zs = zs.assign(Delayed_Recall_Z = lambda x: ((x['Delayed Recall']-20.4)/6.4))
                zs = zs.assign(Number_Span_Test_Forward_Z = lambda x: ((x['Number Span Test Forward']-8.4)/2.3))
                zs = zs.assign(Part_A_Trail_Making_Z = lambda x: ((-x['Part A Trail Making']+27.3)/9.6))
                zs = zs.assign(Part_B_Trail_Making_Z = lambda x: ((-x['Part B Trail Making']+70.1)/33.8))
                zs = zs.assign(MoCA_Z = lambda x: ((x['moca']-26.9)/2.4))
                zs = zs.assign(Categories_Animal_Z = lambda x: ((x['Categories Animal']-22.7)/5.5))
            if 70 <= zs.iloc[row, 1] <= 79:
                zs = zs.assign(Delayed_Recall_Z = lambda x: ((x['Delayed Recall']-26.3)/2.7))
                zs = zs.assign(Number_Span_Test_Forward_Z = lambda x: ((x['Number Span Test Forward']-8.3)/2.3))
                zs = zs.assign(Part_A_Trail_Making_Z = lambda x: ((-x['Part A Trail Making']+31.0)/10.8))
                zs = zs.assign(Part_B_Trail_Making_Z = lambda x: ((-x['Part B Trail Making']+82.7)/41.4))
                zs = zs.assign(MoCA_Z = lambda x: ((x['moca']-26.3)/2.7))
                zs = zs.assign(Categories_Animal_Z = lambda x: ((x['Categories Animal']-21.2)/5.4))
            if 80 <= zs.iloc[row, 1] <= 89:
                zs = zs.assign(Delayed_Recall_Z = lambda x: ((x['Delayed Recall']-16.9)/6.6))
                zs = zs.assign(Number_Span_Test_Forward_Z = lambda x: ((x['Number Span Test Forward']-8.0)/2.3))
                zs = zs.assign(Part_A_Trail_Making_Z = lambda x: ((-x['Part A Trail Making']+36.2)/13.3))
                zs = zs.assign(Part_B_Trail_Making_Z = lambda x: ((-x['Part B Trail Making']+102.0)/55.2))
                zs = zs.assign(MoCA_Z = lambda x: ((x['moca']-25.3)/3.0))
                zs = zs.assign(Categories_Animal_Z = lambda x: ((x['Categories Animal']-19.5)/5.6))
            if 90 <= zs.iloc[row, 1]:
                zs = zs.assign(Delayed_Recall_Z = lambda x: ((x['Delayed Recall']-15.1)/5.8))
                zs = zs.assign(Number_Span_Test_Forward_Z = lambda x: ((x['Number Span Test Forward']-7.6)/2.1))
                zs = zs.assign(Part_A_Trail_Making_Z = lambda x: ((-x['Part A Trail Making']+42.0)/13.4))
                zs = zs.assign(Part_B_Trail_Making_Z = lambda x: ((-x['Part B Trail Making']+140.6)/75.3))
                zs = zs.assign(MoCA_Z = lambda x: ((x['moca']-23.8)/3.5))
                zs = zs.assign(Categories_Animal_Z = lambda x: ((x['Categories Animal']-17.0)/5.4))
            zs = zs.drop(['Age', 'CDR','Delayed Recall','Number Span Test Forward','Part A Trail Making','Part B Trail Making','moca','Categories Animal'], axis = 1)
            
            zs_ab = zs
            zs_ab['DR_ab'] = zs_ab['Delayed_Recall_Z'].apply(lambda x: 1 if x <= -1.5 else 0)
            zs_ab['NSF_ab'] = zs_ab['Number_Span_Test_Forward_Z'].apply(lambda x: 1 if x <= -1.5 else 0)
            zs_ab['TMA_ab'] = zs_ab['Part_A_Trail_Making_Z'].apply(lambda x: 1 if x <= -1.5 else 0)
            zs_ab['TMB_ab'] = zs_ab['Part_B_Trail_Making_Z'].apply(lambda x: 1 if x <= -1.5 else 0)
            zs_ab['MoCA_ab'] = zs_ab['MoCA_Z'].apply(lambda x: 1 if x <= -1.5 else 0)
            zs_ab['Cat_An_ab'] = zs_ab['Categories_Animal_Z'].apply(lambda x: 1 if x <= -1.5 else 0)
            zs_ab = zs_ab.drop(['Delayed_Recall_Z','Number_Span_Test_Forward_Z','Part_A_Trail_Making_Z','Part_B_Trail_Making_Z','MoCA_Z','Categories_Animal_Z'], axis = 1)
            return zs_ab

    
    def alz_diagnose(data):
        #Assigns diagnosis based off GDS and CDR values.
        data = data.drop(['Age', 'Delayed Recall','Number Span Test Forward','Part A Trail Making','Part B Trail Making','moca','Categories Animal'], axis = 1)
        diags = []
        for row in range(data.shape[0]):
            row_sum = data.iloc[row].sum()
            try:
                if row_sum <= 0.5:
                    raise ValueError()
                elif 1.0 <= row_sum <= 2.0:
                    if data.iloc[row, 0] == 1:
                        diags.append('Normal')
                    if data.iloc[row, 0] == 2:
                        diags.append('SCD')
                elif row_sum == 3.5:
                    diags.append('MCI')
                elif row_sum <= 5:
                    diags.append('Probable Dementia')
                elif 6 <= row_sum <= 7:
                    diags.append('Mild Dementia')
                elif 8 <= row_sum <= 9:
                    diags.append('Moderate Dementia')
                elif row_sum == 10:
                    diags.append('Severe Dementia')
                elif row_sum >= 10.5:
                    raise ValueError()
                else:
                    raise ValueError()
            except ValueError:
                diags.append('These diagnostic values are out of range. Please verify values are correct.')
                pass
        return diags
    
    def abnormal_zs(zs_ab):
        cognition = []
        for row in range(zs_ab.shape[0]):
            try:
                if 3<= zs_ab.iloc[row, 0] <= 7:
                    zs_ab_dropped = zs_ab.drop(['GDS'], axis = 1)
                    row_sum = zs_ab_dropped.iloc[row].sum()
                    if row_sum == 0:
                        cognition.append('Normal Cognition')
                    if row_sum == 1:
                        cognition.append('Single Domain Deficient')
                    if row_sum >= 2:
                        cognition.append('Multiple Domains Deficient')
                elif 1<= zs_ab.iloc[row, 0] <= 2:
                    cognition.append('Not Cognitively Impaired')
                else:
                    raise ValueError()
            except ValueError:
                cognition.append('Invalid GDS Value, must be between 1 and 7')
                pass 
        return cognition
    
    def cognitive_domains(zs_ab):
        domains = []
        for row in range(zs_ab.shape[0]):
            try:
                if 1<= zs_ab.iloc[row, 0] <= 2:
                    domains.append('Normal Cognition')
                elif 3<= zs_ab.iloc[row, 0] <= 7:
                    zs_ab_dropped = zs_ab.drop(['GDS'], axis = 1)
                    row_sum = zs_ab_dropped.iloc[row].sum()
                    if row_sum == 0:
                        domains.append('Normal Cognition')
                    if row_sum == 1:
                        if zs_ab_dropped.iloc[row, 0]==1:
                            domains.append('Memory')
                        if zs_ab_dropped.iloc[row, 1]==1:
                            domains.append('Attention')
                        if zs_ab_dropped.iloc[row, 2]==1:
                            domains.append('Processing speed')
                        if zs_ab_dropped.iloc[row, 3]==1:
                            domains.append('Executive Function')
                        if zs_ab_dropped.iloc[row, 4]==1:
                            domains.append('Dementia severity')
                        if zs_ab_dropped.iloc[row, 5]==1:
                            domains.append('Lang. category fluency')
                        else:
                            pass
                    if row_sum >= 2:
                        sub_domains = []
                        if zs_ab_dropped.iloc[row, 0]==1:
                            sub_domains.append('Memory')
                        if zs_ab_dropped.iloc[row, 1]==1:
                            sub_domains.append('Attention')
                        if zs_ab_dropped.iloc[row, 2]==1:
                            sub_domains.append('Processing speed')
                        if zs_ab_dropped.iloc[row, 3]==1:
                            sub_domains.append('Executive Function')
                        if zs_ab_dropped.iloc[row, 4]==1:
                            sub_domains.append('Dementia severity')
                        if zs_ab_dropped.iloc[row, 5]==1:
                            sub_domains.append('Lang. category fluency')
                        else:
                            pass
                        domains.append(sub_domains)
                else:
                    raise ValueError()
            except ValueError:
                domains.append('Values could not be parsed')
                pass    
        return domains
    def run_all(file_path):
        data = AlzDiagnosisAlg.open_dataframe(file_path)
        zs_interp = AlzDiagnosisAlg.z_calc(data)
        diags = AlzDiagnosisAlg.alz_diagnose(data)
        cognition = AlzDiagnosisAlg.abnormal_zs(zs_interp)
        domains = AlzDiagnosisAlg.cognitive_domains(zs_interp)
        
        data = data.drop(['Delayed Recall','Number Span Test Forward','Part A Trail Making','Part B Trail Making','moca','Categories Animal'], axis = 1)
        df5 = pd.DataFrame({'Cognition':cognition, "Cognitive Domains":domains, 'Diagnosis':diags})
        data = data.join(df5)
        
        name,ext = os.path.splitext(file_path)
        data.to_csv(name+'_diag'+ext)
        
        original = r'/Users/jonlinks/Documents/VilcekMastersBMIITPFinalProj/alz_data_diag.csv'
        target = r'/Users/jonlinks/Documents/VilcekMastersBMIITPFinalProj/Results/alz_data_diag.csv'
        shutil.move(original,target)
        return data

# %%
from src.AlzDiagnosisAlg import AlzDiagnosisAlg
file = 'alz_data.csv'
final_data = AlzDiagnosisAlg.run_all(file)

# %%
print(final_data[:50])
print(final_data[50:])
# Out:
#     Age  GDS  CDR                                   Cognition  \
# 0    65    0  0.0  Invalid GDS Value, must be between 1 and 7
# 1    65    0  0.0  Invalid GDS Value, must be between 1 and 7
# 2    65    1  0.0                    Not Cognitively Impaired
# 3    65    1  0.0                    Not Cognitively Impaired
# 4    65    1  0.0                    Not Cognitively Impaired
# 5    90    1  0.0                    Not Cognitively Impaired
# 6    73    0  0.0  Invalid GDS Value, must be between 1 and 7
# 7    74    1  0.0                    Not Cognitively Impaired
# 8    69    1  0.0                    Not Cognitively Impaired
# 9    91    1  0.0                    Not Cognitively Impaired
# 10   63    1  0.0                    Not Cognitively Impaired
# 11   71    1  0.0                    Not Cognitively Impaired
# 12   70    1  0.0                    Not Cognitively Impaired
# 13   70    1  0.0                    Not Cognitively Impaired
# 14   90    1  0.0                    Not Cognitively Impaired
# 15   72    1  0.0                    Not Cognitively Impaired
# 16   73    1  0.0                    Not Cognitively Impaired
# 17   71    1  0.0                    Not Cognitively Impaired
# 18   80    1  0.0                    Not Cognitively Impaired
# 19   76    1  0.0                    Not Cognitively Impaired
# 20   69    1  0.0                    Not Cognitively Impaired
# 21   73    1  0.0                    Not Cognitively Impaired
# 22   83    1  0.0                    Not Cognitively Impaired
# 23   74    2  0.0                    Not Cognitively Impaired
# 24   92    2  0.0                    Not Cognitively Impaired
# 25   54    2  0.0                    Not Cognitively Impaired
# 26   63    2  0.0                    Not Cognitively Impaired
# 27   63    2  0.0                    Not Cognitively Impaired
# 28   66    2  0.0                    Not Cognitively Impaired
# 29   78    2  0.0                    Not Cognitively Impaired
# 30   75    2  0.0                    Not Cognitively Impaired
# 31   92    2  0.0                    Not Cognitively Impaired
# 32   75    2  0.0                    Not Cognitively Impaired
# 33   75    2  0.0                    Not Cognitively Impaired
# 34   93    2  0.0                    Not Cognitively Impaired
# 35   76    2  0.0                    Not Cognitively Impaired
# 36   78    2  0.0                    Not Cognitively Impaired
# 37   79    2  0.0                    Not Cognitively Impaired
# 38   63    2  0.0                    Not Cognitively Impaired
# 39   65    2  0.0                    Not Cognitively Impaired
# 40   68    2  0.0                    Not Cognitively Impaired
# 41   69    2  0.0                    Not Cognitively Impaired
# 42   69    2  0.0                    Not Cognitively Impaired
# 43   68    2  0.0                    Not Cognitively Impaired
# 44   64    2  0.0                    Not Cognitively Impaired
# 45   61    2  0.0                    Not Cognitively Impaired
# 46   74    2  0.0                    Not Cognitively Impaired
# 47   74    2  0.0                    Not Cognitively Impaired
# 48   71    2  0.0                    Not Cognitively Impaired
# 49   73    2  0.0                    Not Cognitively Impaired
#
#              Cognitive Domains  \
# 0   Values could not be parsed
# 1   Values could not be parsed
# 2             Normal Cognition
# 3             Normal Cognition
# 4             Normal Cognition
# 5             Normal Cognition
# 6   Values could not be parsed
# 7             Normal Cognition
# 8             Normal Cognition
# 9             Normal Cognition
# 10            Normal Cognition
# 11            Normal Cognition
# 12            Normal Cognition
# 13            Normal Cognition
# 14            Normal Cognition
# 15            Normal Cognition
# 16            Normal Cognition
# 17            Normal Cognition
# 18            Normal Cognition
# 19            Normal Cognition
# 20            Normal Cognition
# 21            Normal Cognition
# 22            Normal Cognition
# 23            Normal Cognition
# 24            Normal Cognition
# 25            Normal Cognition
# 26            Normal Cognition
# 27            Normal Cognition
# 28            Normal Cognition
# 29            Normal Cognition
# 30            Normal Cognition
# 31            Normal Cognition
# 32            Normal Cognition
# 33            Normal Cognition
# 34            Normal Cognition
# 35            Normal Cognition
# 36            Normal Cognition
# 37            Normal Cognition
# 38            Normal Cognition
# 39            Normal Cognition
# 40            Normal Cognition
# 41            Normal Cognition
# 42            Normal Cognition
# 43            Normal Cognition
# 44            Normal Cognition
# 45            Normal Cognition
# 46            Normal Cognition
# 47            Normal Cognition
# 48            Normal Cognition
# 49            Normal Cognition
#
#                                             Diagnosis
# 0   These diagnostic values are out of range. Plea...
# 1   These diagnostic values are out of range. Plea...
# 2                                              Normal
# 3                                              Normal
# 4                                              Normal
# 5                                              Normal
# 6   These diagnostic values are out of range. Plea...
# 7                                              Normal
# 8                                              Normal
# 9                                              Normal
# 10                                             Normal
# 11                                             Normal
# 12                                             Normal
# 13                                             Normal
# 14                                             Normal
# 15                                             Normal
# 16                                             Normal
# 17                                             Normal
# 18                                             Normal
# 19                                             Normal
# 20                                             Normal
# 21                                             Normal
# 22                                             Normal
# 23                                                SCD
# 24                                                SCD
# 25                                                SCD
# 26                                                SCD
# 27                                                SCD
# 28                                                SCD
# 29                                                SCD
# 30                                                SCD
# 31                                                SCD
# 32                                                SCD
# 33                                                SCD
# 34                                                SCD
# 35                                                SCD
# 36                                                SCD
# 37                                                SCD
# 38                                                SCD
# 39                                                SCD
# 40                                                SCD
# 41                                                SCD
# 42                                                SCD
# 43                                                SCD
# 44                                                SCD
# 45                                                SCD
# 46                                                SCD
# 47                                                SCD
# 48                                                SCD
# 49                                                SCD
#     Age  GDS  CDR                                   Cognition  \
# 50   72    2  0.0                    Not Cognitively Impaired
# 51   74    2  0.0                    Not Cognitively Impaired
# 52   75    2  0.0                    Not Cognitively Impaired
# 53   79    2  0.0                    Not Cognitively Impaired
# 54   73    2  0.0                    Not Cognitively Impaired
# 55   82    3  0.5                  Multiple Domains Deficient
# 56   80    3  0.5                  Multiple Domains Deficient
# 57   80    3  0.5                  Multiple Domains Deficient
# 58   80    3  0.5                  Multiple Domains Deficient
# 59   80    3  0.5                  Multiple Domains Deficient
# 60   84    3  0.5                  Multiple Domains Deficient
# 61   86    3  0.5                  Multiple Domains Deficient
# 62   82    3  0.5                  Multiple Domains Deficient
# 63   73    3  0.5                  Multiple Domains Deficient
# 64   74    3  0.5                     Single Domain Deficient
# 65   79    3  0.5                  Multiple Domains Deficient
# 66   75    3  0.5                     Single Domain Deficient
# 67   73    3  0.5                  Multiple Domains Deficient
# 68   75    3  0.5                     Single Domain Deficient
# 69   76    3  0.5                  Multiple Domains Deficient
# 70   73    3  0.5                  Multiple Domains Deficient
# 71   75    3  0.5                  Multiple Domains Deficient
# 72   81    3  0.5                  Multiple Domains Deficient
# 73   81    4  1.0                     Single Domain Deficient
# 74   81    4  1.0                  Multiple Domains Deficient
# 75   80    4  1.0                  Multiple Domains Deficient
# 76   80    4  1.0                  Multiple Domains Deficient
# 77   82    4  1.0                  Multiple Domains Deficient
# 78   82    4  1.0                  Multiple Domains Deficient
# 79   82    4  1.0                  Multiple Domains Deficient
# 80   83    4  1.0                  Multiple Domains Deficient
# 81   84    4  1.0                  Multiple Domains Deficient
# 82   85    4  1.0                  Multiple Domains Deficient
# 83   74    5  1.0                  Multiple Domains Deficient
# 84   74    5  1.0                  Multiple Domains Deficient
# 85   75    5  1.0                  Multiple Domains Deficient
# 86   79    5  1.0                  Multiple Domains Deficient
# 87   79    5  1.0                  Multiple Domains Deficient
# 88   79    5  1.0                  Multiple Domains Deficient
# 89   78    5  2.0                  Multiple Domains Deficient
# 90   83    5  2.0                  Multiple Domains Deficient
# 91   84    5  2.0                  Multiple Domains Deficient
# 92   85    6  2.0                  Multiple Domains Deficient
# 93   82    6  2.0                  Multiple Domains Deficient
# 94   82    6  2.0                  Multiple Domains Deficient
# 95   80    6  3.0                  Multiple Domains Deficient
# 96   92    7  3.0                  Multiple Domains Deficient
# 97   75    7  3.0                  Multiple Domains Deficient
# 98   79    8  3.0  Invalid GDS Value, must be between 1 and 7
# 99   74    7  3.0                  Multiple Domains Deficient
#
#                                     Cognitive Domains  \
# 50                                   Normal Cognition
# 51                                   Normal Cognition
# 52                                   Normal Cognition
# 53                                   Normal Cognition
# 54                                   Normal Cognition
# 55                    [Attention, Executive Function]
# 56       [Executive Function, Lang. category fluency]
# 57                    [Attention, Executive Function]
# 58  [Processing speed, Executive Function, Lang. c...
# 59  [Attention, Executive Function, Lang. category...
# 60  [Memory, Attention, Processing speed, Executiv...
# 61       [Executive Function, Lang. category fluency]
# 62                       [Memory, Executive Function]
# 63  [Attention, Executive Function, Lang. category...
# 64                             Lang. category fluency
# 65  [Attention, Processing speed, Executive Functi...
# 66                             Lang. category fluency
# 67       [Executive Function, Lang. category fluency]
# 68                             Lang. category fluency
# 69       [Executive Function, Lang. category fluency]
# 70  [Attention, Processing speed, Executive Functi...
# 71                   [Memory, Lang. category fluency]
# 72  [Memory, Processing speed, Executive Function,...
# 73                                 Executive Function
# 74  [Memory, Attention, Processing speed, Executiv...
# 75  [Memory, Attention, Processing speed, Executiv...
# 76  [Memory, Attention, Processing speed, Executiv...
# 77  [Processing speed, Executive Function, Dementi...
# 78  [Processing speed, Executive Function, Dementi...
# 79  [Memory, Attention, Processing speed, Executiv...
# 80  [Memory, Attention, Processing speed, Executiv...
# 81  [Memory, Attention, Processing speed, Executiv...
# 82  [Attention, Processing speed, Executive Functi...
# 83  [Memory, Attention, Processing speed, Executiv...
# 84  [Memory, Attention, Processing speed, Executiv...
# 85  [Memory, Attention, Processing speed, Executiv...
# 86  [Attention, Processing speed, Executive Functi...
# 87  [Memory, Attention, Processing speed, Executiv...
# 88  [Attention, Processing speed, Executive Functi...
# 89  [Attention, Processing speed, Executive Functi...
# 90  [Memory, Attention, Processing speed, Executiv...
# 91  [Memory, Attention, Processing speed, Executiv...
# 92  [Memory, Attention, Processing speed, Executiv...
# 93  [Memory, Attention, Processing speed, Executiv...
# 94  [Memory, Attention, Processing speed, Executiv...
# 95  [Memory, Attention, Processing speed, Executiv...
# 96  [Memory, Attention, Processing speed, Executiv...
# 97  [Memory, Attention, Processing speed, Executiv...
# 98                         Values could not be parsed
# 99  [Memory, Attention, Processing speed, Executiv...
#
#                                             Diagnosis
# 50                                                SCD
# 51                                                SCD
# 52                                                SCD
# 53                                                SCD
# 54                                                SCD
# 55                                                MCI
# 56                                                MCI
# 57                                                MCI
# 58                                                MCI
# 59                                                MCI
# 60                                                MCI
# 61                                                MCI
# 62                                                MCI
# 63                                                MCI
# 64                                                MCI
# 65                                                MCI
# 66                                                MCI
# 67                                                MCI
# 68                                                MCI
# 69                                                MCI
# 70                                                MCI
# 71                                                MCI
# 72                                                MCI
# 73                                  Probable Dementia
# 74                                  Probable Dementia
# 75                                  Probable Dementia
# 76                                  Probable Dementia
# 77                                  Probable Dementia
# 78                                  Probable Dementia
# 79                                  Probable Dementia
# 80                                  Probable Dementia
# 81                                  Probable Dementia
# 82                                  Probable Dementia
# 83                                      Mild Dementia
# 84                                      Mild Dementia
# 85                                      Mild Dementia
# 86                                      Mild Dementia
# 87                                      Mild Dementia
# 88                                      Mild Dementia
# 89                                      Mild Dementia
# 90                                      Mild Dementia
# 91                                      Mild Dementia
# 92                                  Moderate Dementia
# 93                                  Moderate Dementia
# 94                                  Moderate Dementia
# 95                                  Moderate Dementia
# 96                                    Severe Dementia
# 97                                    Severe Dementia
# 98  These diagnostic values are out of range. Plea...
# 99                                    Severe Dementia
