# %%
from src.AlzDiagnosisAlg import AlzDiagnosisAlg
AlzDiagnosisAlg.run_all('alz_data.csv')
# Out:
#     Age  GDS  CDR                                   Cognition  \
# 0    65    0  0.0  Invalid GDS Value, must be between 1 and 7
# 1    65    0  0.0  Invalid GDS Value, must be between 1 and 7
# 2    65    1  0.0                    Not Cognitively Impaired
# 3    65    1  0.0                    Not Cognitively Impaired
# 4    65    1  0.0                    Not Cognitively Impaired
# ..  ...  ...  ...                                         ...
# 95   80    6  3.0                  Multiple Domains Deficient
# 96   92    7  3.0                  Multiple Domains Deficient
# 97   75    7  3.0                  Multiple Domains Deficient
# 98   79    8  3.0  Invalid GDS Value, must be between 1 and 7
# 99   74    7  3.0                  Multiple Domains Deficient
#
#                                     Cognitive Domains  \
# 0                          Values could not be parsed
# 1                          Values could not be parsed
# 2                                    Normal Cognition
# ...

# %%
import pandas
data = pandas.read_csv('/Users/jonlinks/Documents/VilcekMastersBMIITPFinalProj/Results/alz_data_diag.csv')
print(data[:50])
print(data[50:])
# Out:
#     Unnamed: 0  Age  GDS  CDR                                   Cognition  \
# 0            0   65    0  0.0  Invalid GDS Value, must be between 1 and 7
# 1            1   65    0  0.0  Invalid GDS Value, must be between 1 and 7
# 2            2   65    1  0.0                    Not Cognitively Impaired
# 3            3   65    1  0.0                    Not Cognitively Impaired
# 4            4   65    1  0.0                    Not Cognitively Impaired
# 5            5   90    1  0.0                    Not Cognitively Impaired
# 6            6   73    0  0.0  Invalid GDS Value, must be between 1 and 7
# 7            7   74    1  0.0                    Not Cognitively Impaired
# 8            8   69    1  0.0                    Not Cognitively Impaired
# 9            9   91    1  0.0                    Not Cognitively Impaired
# 10          10   63    1  0.0                    Not Cognitively Impaired
# 11          11   71    1  0.0                    Not Cognitively Impaired
# ...
